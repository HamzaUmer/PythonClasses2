# %% [markdown]
# # Data Loading, Storage, and File Formats

# %%
import os
a=os.listdir('.')
a
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.conda',
#  '.condarc',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jssc',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.mchp_packs',
#  '.mplabcomm',
#  '.packettracer',
#  '.pylint.d',
#  '.thumbnails',
#  '.viminfo',
#  '.vscode',
#  '13july.ipynb',
#  '14344d425e4e704f1932921b8d226ec4.jpg',
#  '3D Objects',
#  'abc.csv',
#  'abc.json',
#  'abc.txt',
#  'advanced_ip_scanner_Aliases.bin',
#  'advanced_ip_scanner_Comments.bin',
#  'advanced_ip_scanner_MAC.bin',
#  'alphabet_list.json',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'ASSIGNMENT.ipynb',
#  'ATM MACHINE.ipynb',
#  'Cat house.ipynb',
#  'Celsius to fahrenheit.ipynb',
#  'Child class.ipynb',
#  'Cisco Packet Tracer 6.2sv',
#  'Cisco Packet Tracer 7.2',
#  'Classes example(9-1).ipynb',
#  'Classes example(9-2).ipynb',
#  'Classes Example(9-4).ipynb',
#  'Contacts',
#  'Cookies',
#  'Default Parameter 1.ipynb',
# ...

# %%
import pandas as pd

# %% [markdown]
# # read_csv

# %% [markdown]
# load delimited data from a file,URL, or file-like object; use comma as default delimiter

# %%
data = pd.read_csv('abc.csv')

# %%
data
# Out:
#    Year          Event          Winner
# 0  1995  Best-KeptLawn            None
# 1  1999      Gobstones  Welch National
# 2  2006      World Cup     Burkina Faso

# %%
pd.read_csv('abc.csv',header=None)#header none
# Out:
#       0              1                2
# 0  Year          Event          Winner
# 1  1995  Best-KeptLawn            None
# 2  1999      Gobstones  Welch National
# 3  2006      World Cup     Burkina Faso

# %%
pd.read_csv('abc.csv',names=['a','b','c'])#for default column name
# Out:
#       a              b                c
# 0  Year          Event          Winner
# 1  1995  Best-KeptLawn            None
# 2  1999      Gobstones  Welch National
# 3  2006      World Cup     Burkina Faso

# %%
pd.read_csv('abc.csv',names=['a','b','c'],index_col='c')#Indexing through any column
# Out:
#                     a              b
# c
# Winner           Year          Event
# None             1995  Best-KeptLawn
# Welch National   1999      Gobstones
# Burkina Faso     2006      World Cup

# %%
pd.read_csv('abc.csv',index_col=['Year','Event'])
# Out:
#                             Winner
# Year Event
# 1995 Best-KeptLawn            None
# 1999 Gobstones      Welch National
# 2006 World Cup         Burkina Faso

# %%
pd.isnull(data)#if null return True else False
# Out:
#     Year  Event  Winner
# 0  False  False    False
# 1  False  False    False
# 2  False  False    False

# %%
pd.read_csv('abc.csv',na_values=[1995,1999])
# Out:
#      Year          Event          Winner
# 0     NaN  Best-KeptLawn            None
# 1     NaN      Gobstones  Welch National
# 2  2006.0      World Cup     Burkina Faso

# %% [markdown]
# # Reading Text file in pieces

# %%
pd.options.display.max_rows = 2 #display maximum 2 rows
pd.read_csv('abc.csv')
# Out:
#     Year          Event       Winner
# 0   1995  Best-KeptLawn         None
# ..   ...            ...           ...
# 2   2006      World Cup  Burkina Faso
#
# [3 rows x 3 columns]

# %%
pd.options.display.max_rows = None
pd.read_csv('abc.csv')
# Out:
#    Year          Event          Winner
# 0  1995  Best-KeptLawn            None
# 1  1999      Gobstones  Welch National
# 2  2006      World Cup     Burkina Faso

# %%
pd.read_csv('whatever.csv',nrows=2)#load 2 rows
# Out:
#    Year           Event          Winner
# 0  1995  Best-Kept Lawn            None
# 1  1999       Gobstones  Welch National

# %%
chunkread = pd.read_csv('whatever.csv',chunksize=1)#To read a file in
chunkread

# %%
for i in chunkread:
    print(i)
# Out:
#    Year           Event Winner
# 0  1995  Best-Kept Lawn   None
#    Year      Event          Winner
# 1  1999  Gobstones  Welch National
#    Year      Event        Winner
# 2  2006  World cup  Burkino Faso
#    Year       Event  Winner
# 3  2011  Butter Cup  France
#    Year      Event        Winner
# 4  2006  World cup  Burkino Faso
#    Year       Event  Winner
# 5  2011  Butter Cup  France

# %%
import csv
#for any file with a single -character delimiter , you can use python's
#To use it,pass any open file or file like object to csv.reader:
f = open('whatever.csv')
reader=csv.reader(f)
#reader=list(csv.reader(f))#without loop
reader

# %%
for line in reader:
    print(line)
# Out:
# ['Year', 'Event', 'Winner']
# ['1995', 'Best-Kept Lawn', 'None']
# ['1999', 'Gobstones', 'Welch National']
# ['2006', 'World cup', 'Burkino Faso']
# ['2011', 'Butter Cup', 'France']
# ['2006', 'World cup', 'Burkino Faso']
# ['2011', 'Butter Cup', 'France']

# %%
with open('whatever.csv') as f:
    lines = list(csv.reader(f))
lines
# Out:
# [['Year', 'Event', 'Winner'],
#  ['1995', 'Best-Kept Lawn', 'None'],
#  ['1999', 'Gobstones', 'Welch National'],
#  ['2006', 'World cup', 'Burkino Faso'],
#  ['2011', 'Butter Cup', 'France'],
#  ['2006', 'World cup', 'Burkino Faso'],
#  ['2011', 'Butter Cup', 'France']]

# %%
header, values = lines[0], lines[1:]
data_dict = {h: v for h, v in zip(header, zip(*values))}

# %%
data_dict
# Out:
# {'Year': ('1995', '1999', '2006', '2011', '2006', '2011'),
#  'Event': ('Best-Kept Lawn',
#   'Gobstones',
#   'World cup',
#   'Butter Cup',
#   'World cup',
#   'Butter Cup'),
#  'Winner': ('None',
#   'Welch National',
#   'Burkino Faso',
#   'France',
#   'Burkino Faso',
#   'France')}

# %%
x =[12,3,4,5,6]
y=[1,2,3]
q=[4,5,6]
z=zip(x,y,q)
for z in z:
    print(z)
# Out:
# (12, 1, 4)
# (3, 2, 5)
# (4, 3, 6)

# %% [markdown]
# # JSON Data

# %% [markdown]
# JavaScript Object Notation

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"], 
"pet": null, 
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},              
{"name": "Katie", "age": 38,              
"pets": ["Sixes", "Stache", "Cisco"]}] } 
""" 
obj
# Out:
# '\n{"name": "Wes",\n"places_lived": ["United States", "Spain", "Germany"], \n"pet": null, \n"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},              \n{"name": "Katie", "age": 38,              \n"pets": ["Sixes", "Stache", "Cisco"]}] } \n'

# %%
import json

# %%
result = json.loads(obj)

# %%
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# # read_html

# %% [markdown]
# # Interacting with Web APIs

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29359',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29359/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29359/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29359/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29359',
#   'id': 516631792,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzM1ODY0NjYy',
#   'number': 29359,
#   'title': 'GH 16051: DataFrame.replace() overwrites when values are non-numeric',
#   'user': {'login': 'pv8473h12',
#    'id': 40920480,
#    'node_id': 'MDQ6VXNlcjQwOTIwNDgw',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/40920480?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pv8473h12',
#    'html_url': 'https://github.com/pv8473h12',
# ...

# %%
data[0]['title']
# Out:
# 'GH 16051: DataFrame.replace() overwrites when values are non-numeric'

# %%
issues = pd.DataFrame(data, columns=['number','title','labels','state'])
issues
# Out:
#     number                                              title  \
# 0    29359  GH 16051: DataFrame.replace() overwrites when ...
# 1    29358  TST: Apply method broken for empty integer ser...
# 2    29357  ensure consistent structure for groupby on ind...
# 3    29356     TST: new test for subset of a MultiIndex dtype
# 4    29355  TST: Test type issue fix in empty groupby from...
# 5    29354                                        Pv feature2
# 6    29353  BUG: Issue #29128 Series.var not returning the...
# 7    29352  TST: Add test to check category dtype remains ...
# 8    29349  Local test failure: AssertionError: Series are...
# 9    29348  GH14422: BUG: to_numeric doesn't work uint64 n...
# 10   29346  TST: Adding styler applymap multindex & code t...
# 11   29344  TST: Test for Boolean Series with missing to C...
# 12   29341                           black==19.10b0 breaks CI
# 13   29340                           28926 mypy test toffsets
# ...

# %% [markdown]
# # Web scraping

# %%
import bs4
from urllib.request import urlopen as uReq
from urllib.request import Request 
from bs4 import BeautifulSoup as soup

# %%
my_url = 'https://www.newegg.com/Laptops-Notebooks/Category/ID-223'

# %%
uClient = uReq(my_url)

# %%
page_html = uClient.read()

# %%
uClient.close()

# %%
page_html
# Out:
# b'<!DOCTYPE HTML>\r\n<html lang="en-us">\r\n<head>\r\n<script src="//imk.neweggimages.com/WebResource/Scripts/usa/strc/usa_prod/d2f967b83a0c92b19d9b572545fdbdc3d591f6f5/biztralib.js"></script>\n        <script src="//imk.neweggimages.com/webresource/scripts/plugin/inhousebiztra.js"></script>\r\n\t<title>Laptops and Notebook Computers - Newegg.com</title>\r\n\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n\t<meta name="referrer" content="always">\r\n\t<meta name="keywords" content="Laptop computers, laptops, notebooks,">\r\n\t<meta name="description" content="Shop a wide selection of Laptops and Notebooks from ACER, ASUS, Lenovo &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!">\r\n\t<meta property="og:image" content="https://c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png">\r\n\t<meta property="og:description" content="Shop a wide selection of Laptops and Notebooks from ACER, ASUS, Lenovo &amp; more! N
# ...

# %%
page_soup = soup(page_html,"html.parser")

# %%
page_soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-us">
# <head>
# <script src="//imk.neweggimages.com/WebResource/Scripts/usa/strc/usa_prod/d2f967b83a0c92b19d9b572545fdbdc3d591f6f5/biztralib.js"></script>
# <script src="//imk.neweggimages.com/webresource/scripts/plugin/inhousebiztra.js"></script>
# <title>Laptops and Notebook Computers - Newegg.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="always" name="referrer"/>
# <meta content="Laptop computers, laptops, notebooks," name="keywords"/>
# <meta content="Shop a wide selection of Laptops and Notebooks from ACER, ASUS, Lenovo &amp; more! Newegg offers the best prices, fast shipping and top-rated customer service!" name="description"/>
# <meta content="https://c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png" property="og:image"/>
# ...

# %%
page_soup.h1
# Out:
# <h1 class="page-title-text">Laptops / Notebooks</h1>

# %%
page_soup.p
# Out:
# <p>Newegg.com - A great place to buy computers, computer parts, electronics, software, accessories, and DVDs online. With great prices, fast shipping, and top-rated customer service - Newegg shopping upgraded ™</p>

# %%
containers = page_soup.find_all("div",{"class":"item-container"})

# %%
containers
# Out:
# [<div class="item-container">
#  <!--product image-->
#  <a class="item-img" href="https://www.newegg.com/icicle-silver-metal-asus-zenbook-ux533fd-ns76-gaming-entertainment/p/N82E16834235117?Item=N82E16834235117">
#  <div class="item-badges">
#  </div>
#  <img alt='ASUS ZenBook15.6" Intel Whiskey Lake i7-8565U, 16 GB DDR4, 1 TB PCIe SSD, GTX 1050, IR Camera, Windows 10 Pro - Icicle Silver Ultra Slim Compact FHD 4-Way NanoEdge - UX533FD-NS76 Newegg Exclusive' class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/34-235-117-V01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title='ASUS ZenBook15.6" Intel Whiskey Lake i7-8565U, 16 GB DDR4, 1 TB PCIe SSD, GTX 1050, IR Camera, Windows 10 Pro - Icicle Silver Ultra Slim Compact FHD 4-Way NanoEdge - UX533FD-NS76 Newegg Exclusive'>
#  </img></a>
#  <div class="item-info">
#  <!--brand info-->
#  <div class="item-branding">
# ...

# %%
len(containers)
# Out:
# 12

# %%
contain = containers[0]

# %%
contain
# Out:
# <div class="item-container">
# <!--product image-->
# <a class="item-img" href="https://www.newegg.com/icicle-silver-metal-asus-zenbook-ux533fd-ns76-gaming-entertainment/p/N82E16834235117?Item=N82E16834235117">
# <div class="item-badges">
# </div>
# <img alt='ASUS ZenBook15.6" Intel Whiskey Lake i7-8565U, 16 GB DDR4, 1 TB PCIe SSD, GTX 1050, IR Camera, Windows 10 Pro - Icicle Silver Ultra Slim Compact FHD 4-Way NanoEdge - UX533FD-NS76 Newegg Exclusive' class="lazy-img" data-effect="fadeIn" data-src="//c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/34-235-117-V01.jpg" src="//c1.neweggimages.com/WebResource/Themes/2005/Nest/blank.gif" title='ASUS ZenBook15.6" Intel Whiskey Lake i7-8565U, 16 GB DDR4, 1 TB PCIe SSD, GTX 1050, IR Camera, Windows 10 Pro - Icicle Silver Ultra Slim Compact FHD 4-Way NanoEdge - UX533FD-NS76 Newegg Exclusive'>
# </img></a>
# <div class="item-info">
# <!--brand info-->
# <div class="item-branding">
# ...

# %%
contain.img['title']
# Out:
# 'ASUS ZenBook15.6" Intel Whiskey Lake i7-8565U, 16 GB DDR4, 1 TB PCIe SSD, GTX 1050, IR Camera, Windows 10 Pro - Icicle Silver Ultra Slim Compact FHD 4-Way NanoEdge - UX533FD-NS76 Newegg Exclusive'

# %%
filename = "products.csv"
f = open(filename,"w")
header = "brand, product_name, shopping\n"
f.write(header)
# Out:
# 30

# %%
for container in containers:
    brand = container.div.div.a.img["title"]
    
    title_container = container.findAll("a",{"class":"item-title"})
    product_name = title_container[0].text
    
    shipping_container= container.findAll("li",{"class":"price-ship"})
